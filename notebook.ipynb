# %%
from utils import plot_series
from DGP import DGP_sample
from trend_functions import trend_linear, trend_piecewise, trend_exponential, trend_logarithmic, trend_wave, trend_polynomial, trend_recovery

# %%
df = DGP_sample(100,400,300,trend_function=trend_linear, num_samples=50)
plot_series(df, title = "Simulated DGP (Linear trend)")

# %%
df = DGP_sample(100,300,80,trend_function=trend_piecewise, num_samples=50)
plot_series(df, title = "Simulated DGP (Piecewise trend)")

# %%
df = DGP_sample(500,300,100,trend_function=trend_exponential, num_samples=60)
plot_series(df, title = "Simulated DGP (Exponential trend)")

# %%
df = DGP_sample(10000,4000,1500,trend_function=trend_logarithmic, num_samples=50)
plot_series(df, title = "Simulated DGP (Logarithmic trend)")

# %%
df = DGP_sample(100,400,200,trend_function=trend_wave, num_samples=70)
plot_series(df, title = "Simulated DGP (Wave trend)")

# %%
df = DGP_sample(100,.2,.1,trend_function=trend_polynomial, num_samples=50, seasonality_mode='relative', noise_mode='relative')
plot_series(df, title = "Simulated DGP (Polynomial trend)")

# %%
df = DGP_sample(.5,15,10,trend_function=trend_recovery, num_samples=50)
plot_series(df, title = "Simulated DGP (Recovery trend)")
